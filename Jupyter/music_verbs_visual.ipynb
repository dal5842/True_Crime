# %%
import os

folder_path = '/Users/raasheemishra/Documents/GitHub/True_Crime/music-only-text'
texts = []
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
            texts.append(file.read())
full_text = ' '.join(texts)

# %%
import spacy

nlp = spacy.load("en_core_web_sm")  
doc = nlp(full_text)

adjectives = [token.text.lower() for token in doc if token.pos_ == 'ADJ']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import spacy
#       3 nlp = spacy.load("en_core_web_sm")
#       4 doc = nlp(full_text)
#
# ModuleNotFoundError: No module named 'spacy'

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3: No module named spacy

# %%
# !pip3 install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached spacy-3.8.5-cp39-cp39-macosx_11_0_arm64.whl (6.3 MB)
# ...
#   Using cached typer-0.15.2-py3-none-any.whl (45 kB)
# ...
#   Using cached murmurhash-1.0.12-cp39-cp39-macosx_11_0_arm64.whl (26 kB)
# ...
#      |████████████████████████████████| 443 kB 2.2 MB/s eta 0:00:01
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# ...
#   Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# ...
#   Using cached thinc-8.3.6-cp39-cp39-macosx_11_0_arm64.whl (848 kB)
# ...
#   Using cached preshed-3.0.9-cp39-cp39-macosx_11_0_arm64.whl (129 kB)
# ...
#   Using cached srsly-2.5.1-cp39-cp39-macosx_11_0_arm64.whl (635 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# ...
#   Using cached cymem-2.0.11-cp39-cp39-macosx_11_0_arm64.whl (42 kB)
# ...

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# /Users/raasheemishra/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 12.8 MB 3.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from collections import Counter

adj_freq = Counter(adjectives)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from collections import Counter
# ----> 3 adj_freq = Counter(adjectives)
#
# NameError: name 'adjectives' is not defined

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(full_text)

adjectives = [token.text.lower() for token in doc if token.pos_ == 'ADJ']
# Out:
# /Users/raasheemishra/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
print(adjectives[:10])
# Out:
# ['♪', '♪', '♪', '♪', '♪', '♪', 'last', '♪', '♪', '♪']

# %%
from collections import Counter

adj_freq = Counter(adjectives)

# %%
import matplotlib.pyplot as plt

most_common = adj_freq.most_common(20)
words, counts = zip(*most_common)

plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Verb')
plt.ylabel('Frequency')
plt.title('True Crime Soundtrack')
plt.tight_layout()

plt.savefig('music_verb_frequency.svg', format='svg')
plt.show()

# %%
import os
import spacy
import matplotlib.pyplot as plt
from collections import Counter

# Step 1: Read all text files from a folder
folder_path = '/Users/raasheemishra/Documents/GitHub/True_Crime/music-only-text' 
texts = []
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
            texts.append(file.read())
full_text = ' '.join(texts)

nlp = spacy.load("en_core_web_sm")
doc = nlp(full_text)

verbs = [token.text.lower() for token in doc if token.pos_ == 'VERB']

verb_freq = Counter(verbs)

most_common = verb_freq.most_common(20)
words, counts = zip(*most_common)

plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Verb')
plt.ylabel('Frequency')
plt.title('True Crime Soundtrack: Through Verbs')
plt.tight_layout()

plt.savefig('music_verb_frequency.svg', format='svg')
plt.show()
